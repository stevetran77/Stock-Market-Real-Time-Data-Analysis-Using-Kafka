# %%
pip install s3fs

# %%
import pandas as pd
from kafka import KafkaConsumer
from time import sleep
from json import loads
import json

# %%
consumer = KafkaConsumer(
    'demo_testing',
     bootstrap_servers=['47.129.234.154:9092'], #add your IP here
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
# for c in consumer:
#     print(c.value)

# %%
# Import S3FileSystem
from s3fs import S3FileSystem

# Initialize S3FileSystem
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://kafka-stock-market-steve/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
