# %%
pip install kafka-python

# %%
pip install pandas

# %%
import pandas as pd
from kafka import KafkaProducer
from time import sleep
from json import dumps
import json

# %%
## Create a producer
producer = KafkaProducer(bootstrap_servers=['47.129.234.154:9092'],
                         value_serializer=lambda x: 
                         dumps(x).encode('utf-8'))

# %%
producer.send('demo_testing', value={'name':'steve'})

# %%
# Clear the producer
# producer.flush()

# %%
## Import CSV file
df = pd.read_csv('indexProcessed.csv')

# %%
df.head()

# %%
# Convert dataframe into dictionary and send to Consumer
while True:
    dict_stock = df.sample().to_dict(orient='records')[0]
    producer.send('demo_testing', value=dict_stock)
